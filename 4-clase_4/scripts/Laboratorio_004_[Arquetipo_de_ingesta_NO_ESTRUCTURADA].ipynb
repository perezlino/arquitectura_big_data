# %% [markdown]
# ### 1. Instalación e inicialización de Spark

# %%
# Actualización de los repositorios de UBUNTU
# !sudo apt-get update

# %%
# Instalación de JAVA
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# Descarga de SPARK
# !wget -q https://downloads.apache.org/spark/spark-2.4.8/spark-2.4.8-bin-hadoop2.7.tgz

# %%
# Des-zipeado del instalador
# !tar xf spark-2.4.8-bin-hadoop2.7.tgz

# %%
# Instalación de Spark en Python
# !pip install -q findspark

# %%
# Configuración de variables de entorno
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.8-bin-hadoop2.7"

# %%
# Inicialización de Spark
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()

# %%
# Verificación de la sesión de Spark
spark

# %% [markdown]
# ### 2. Creación de estructura de directorios para las capas LANDING_TMP y LANDING

# %%
# Librería para manipulación del sistema de archivos
import os

# %%
# Supongamos que vamos a ingestar del servidor "SERVER_IMG" archivos de imagenes de "ANIMALES"
#
# - ENTIDAD ANIMALES

# %%
# Creamos el directorio asociado al servidor desde donde vamos a ingestar los datos para la capa "LANDING_TMP"
os.mkdir('/content/drive/MyDrive/DATALAKE/LANDING_TMP/SERVER_IMG')

# %%
# Creamos el directorio para "ANIMALES" en "LANDING_TMP"
os.mkdir('/content/drive/MyDrive/DATALAKE/LANDING_TMP/SERVER_IMG/ANIMALES')

# %%
# Creamos el directorio asociado al servidor desde donde vamos a ingestar los datos para la capa "LANDING"
os.mkdir('/content/drive/MyDrive/DATALAKE/LANDING/SERVER_IMG')

# %%
# Creamos el directorio para "ANIMALES" en "LANDING"
os.mkdir('/content/drive/MyDrive/DATALAKE/LANDING/SERVER_IMG/ANIMALES')

# %% [markdown]
# ### 3. Subir archivos a la capa LANDING_TMP

# %%
# Subimos las imagenes de ANIMALES (los subdirectorios de IMAGENES) a "LANDING_TMP/SERVER_IMG/ANIMALES"

# %% [markdown]
# ### 4. Visualizamos una imagen

# %%
# Importamos una libreria que nos permitirá visualizar imágenes
from PIL import Image

# %%
# Tendremos una estructura de tipos semi estructurada
imagen = Image.open('/content/drive/MyDrive/DATALAKE/LANDING_TMP/SERVER_IMG/ANIMALES/AVE/imagen1.jpg')
imagen

# %% [markdown]
# ### 5. Movimiento de las imagenes a la zona LANDING

# %%
# Importamos una libreria que nos permitirá copiar datos
import shutil

# %%
# Copiamos los datos en la partición de la fecha correspondiente en "LANDING" para "ANIMALES"
shutil.copytree(
    "/content/drive/MyDrive/DATALAKE/LANDING_TMP/SERVER_IMG/ANIMALES",
    "/content/drive/MyDrive/DATALAKE/LANDING/SERVER_IMG/ANIMALES/2018-04-19"
)
